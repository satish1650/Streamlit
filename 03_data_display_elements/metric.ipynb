# %% [markdown]
# ✅ `st.metric()`
#
# `st.metric()` is used to display **key performance indicators (KPIs)** — like a single value with an optional **delta** — often used in **dashboards**.

# %% [markdown]
# ```Python
# 🔸Example
#
# import streamlit as st
#
# st.metric(label="Revenue", value="$10M", delta="+5%")
# st.metric(label="Revenue", value="$10M", delta="-5%")

# %% [markdown]
# #### Output
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🔸Example
#
# ```Python
# import streamlit as st
#
# st.metric(label="📈 Monthly Sales", value="₹2.5 Cr", delta="+12%")
# st.metric(label="📉 Customer Churn", value="3.2%", delta="-0.4%")

# %% [markdown]
# #### Output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `inverse` will color **negative** numbers **green**, and **positive** ones **red** — useful for things like **expenses** or **loss**.

# %% [markdown]
# 🔸With `delta_color` example:
#
# ```python
# # using delta_color
# st.metric("Net Profit", "$2M", "-3%", delta_color="inverse")
# st.metric("Net Profit", "$2M", "+3%", delta_color="inverse")
# st.metric("Net Profit", "$2M", "-3%", delta_color="normal")
# st.metric("Net Profit", "$2M", "+3%", delta_color="normal")
# st.metric("Net Profit", "$2M", "-3%", delta_color="off")
# st.metric("Net Profit", "$2M", "+3%", delta_color="off")

# %% [markdown]
# #### Output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```Python
# # Use in columns for side-by-side layout:
# col1, col2, col3 = st.columns(3)
#
# col1.metric("Users", "12,500", "+8%")
# col2.metric("Bounce Rate", "34%", "-2%")
# col3.metric("Revenue", "₹1.2 Cr", "+5.5%")

# %% [markdown]
# #### Output
# ![image.png](attachment:image.png)
