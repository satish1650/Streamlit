# %% [markdown]
# <hr>
#
# ### `st.session_state()`
# <hr>
#
# `st.session_state` is a **dictionary-like object** used to **store variables across reruns** in a **Streamlit** app. It lets you maintain state - like storing user input, selections, flags, counters, etc.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### `Example-1`
# ```python
# import streamlit as st
#
# # Initialize state
# if 'count' not in st.session_state:
#     st.session_state.count= 0
#
# # Button to increment
# if st.button("Increment Count"):
#     st.session_state.count += 1
#
# # Display the current count
# st.write(f"Current Count: {st.session_state.count}")
# ```
# <hr>
#
# #### `Streamlit Output`
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### `Example-2`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png)
#
# <hr>
#
# #### `Example-3`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
#
# # Set the value using the key-value syntax
#
# if "key" not in st.session_state:
#     st.session_state["key"] = "value"
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-2.png](attachment:image-2.png)
#
# <hr>
#
# #### `Example-4`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
#
# # Set the value using the key-value syntax
#
# if "key" not in st.session_state:
#     st.session_state["key"] = "value"
#
# # Set the value using the attribute syntax
# if "attribute" not in st.session_state:
#     st.session_state.attribute = "another value"
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# #### `Example-5`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
#
# # Set the value using the key-value syntax
#
# if "key" not in st.session_state:
#     st.session_state["key"] = "value"
#
# # Set the value using the attribute syntax
# if "attribute" not in st.session_state:
#     st.session_state.attribute = "another value"
#
# if "attribute1" not in st.session_state:
#     st.session_state.attribute = "second value"
#
# if "attribute1" not in st.session_state:
#     st.session_state.attribute1 = "third value"
#
# if "xyz" not in st.session_state:
#     st.session_state.attribute = "fourth value"
#
# if "abc" not in st.session_state:
#     st.session_state.abc = "fifth value"
#
# if "counter" not in st.session_state:
#     st.session_state.counter = 0
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-4.png](attachment:image-4.png)
#
# <hr>
#
# #### `Example-6`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
#
# # Set the value using the key-value syntax
#
# if "key" not in st.session_state:
#     st.session_state["key"] = "value"
#
# # Set the value using the attribute syntax
# if "attribute" not in st.session_state:
#     st.session_state.attribute = "another value"
#
# # Read value from session state
# st.write(f"Reading with key-value syntax: {st.session_state['key']}")
# st.write(f"Reading with attribute syntax: {st.session_state.attribute}")
#
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-5.png](attachment:image-5.png)
#
# <hr>
#
# #### `Example-7`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
#
# # Set the value using the key-value syntax
# if "key" not in st.session_state:
#     st.session_state["key"] = "value"
#
# # Set the value using the attribute syntax
# if "attribute" not in st.session_state:
#     st.session_state.attribute = "another value"
#
# # Read value from session state
# st.write(f"Reading with key-value syntax: {st.session_state['key']}")
# st.write(f"Reading with attribute syntax: {st.session_state.attribute}")
#
# # Update values in state
# st.session_state['key'] = "new value"
# st.session_state.attribute = "updated value"
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-3.png](attachment:image-3.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
# <hr>
#
# #### `Example-8`
# ```Python
# import streamlit as st
#
# st.title("Stateful Apps with Streamlit")
#
# st.write("Here is the session state:")
# st.write(st.session_state)
# st.button("Update Session State")
#
# # Set the value using the key-value syntax
# if "key" not in st.session_state:
#     st.session_state["key"] = "value"
#
# # Set the value using the attribute syntax
# if "attribute" not in st.session_state:
#     st.session_state.attribute = "another value"
#
# # Read value from session state
# st.write(f"Reading with key-value syntax: {st.session_state['key']}")
# st.write(f"Reading with attribute syntax: {st.session_state.attribute}")
#
# # Update values in state
# st.session_state['key'] = "new value"
# st.session_state.attribute = "updated value"
#
# # Delete item in state
# del st.session_state['key']
# ```
# <hr>
#
# #### `Streamlit Output`
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
