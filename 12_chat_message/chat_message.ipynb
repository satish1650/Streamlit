# %% [markdown]
# <hr>
#
# ### `st.chat_message()`
# **st.chat_message()** is a Streamlit function that’s part of the **chat UI components**, It helps us to build chatbot-style apps.
#
# It’s used to display a chat bubble (either from the user or the assistant) in the app’s conversation history.
#
# <hr>
#
# ![image.png](attachment:image.png)
#
# <hr>

# %% [markdown]
# #### `Example-1`
# ```Python
# import streamlit as st
#
# st.title("Simple Chat Example")
#
# # User message bubble
# with st.chat_message("user"):
#     st.write("Hello, How are you?")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png)
#
# <hr>
#
# #### `Example-2`
# ```Python
# import streamlit as st
#
# st.title("Simple Chat Example")
#
# # User message bubble
# with st.chat_message("user"):
#     st.write("Hello, How are you?")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png)
#
# <hr>
#
# #### `Example-3`
# ```Python
# import streamlit as st
#
# st.title("Simple Chat Example")
#
# # User message bubble
# with st.chat_message("user"):
#     st.write("Hello, How are you?")
#
# # User message bubble
# with st.chat_message("user"):
#     st.write("Hello, What is Streamlit?")
#
# # Assistant message bubble
# with st.chat_message("assistant"):
#     st.write("""Streamlit is an open-source Python library that simplifies the creation and sharing of custom web applications for machine learning and data science. It enables users to transform Python scripts into interactive web apps with minimal code, eliminating the need for extensive knowledge of web development technologies like HTML, CSS, or JavaScript.""")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# #### `Example-4: chat_message without with`
# ```Python
# import streamlit as st
#
# st.title("Simple Chat Example")
#
# st.chat_message("User")
# st.write("How are you?")
# st.chat_message("assistant")
# st.write("I'm doing great! How can I help you today?")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-4.png](attachment:image-4.png)
#
# <hr>

# %% [markdown]
# #### `Simple Chat Example`
# ```Python
# import streamlit as st
#
# st.title("Simple Chat Example")
#
# # # st.chat_message() without with
# # st.chat_message("User")
# # st.write("How are you?")
# # st.chat_message("assistant")
# # st.write("I'm doing great! How can I help you today?")
#
# # # st.chat_message() using with
# # # User message bubble
# with st.chat_message("user"):
#     st.write("Hello, How are you?")
#
# # Assistant message bubble
# with st.chat_message("assistant"):
#     st.write("I'm doing great! How can I help you today?")
#
# # User message bubble
# with st.chat_message("user"):
#     st.write("Hello, What is Streamlit?")
#
# # Assistant message bubble
# with st.chat_message("assistant"):
#     st.write("""Streamlit is an open-source Python library that simplifies the creation and sharing of custom web applications for machine learning and data science. It enables users to transform Python scripts into interactive web apps with minimal code, eliminating the need for extensive knowledge of web development technologies like HTML, CSS, or JavaScript.""")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png)
#
# <hr>
