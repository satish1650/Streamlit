# %% [markdown]
# <hr>
#
# ### Exercise: State Management
# <hr>

# %% [markdown]
# #### `Exercise-1`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png)
#
# <hr>
#
# #### `Exercise-2`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png)
#
# <hr>
#
# #### `Exercise-3`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     st.write("Kelvin = ", st.session_state['kelvin'])
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-2.png](attachment:image-2.png)
#
# <hr>
#
# #### `Exercise-4`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-3.png](attachment:image-3.png)
#
# <hr>
#
# #### `Exercise-4`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
# <hr>
#
# #### `Exercise-5`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
# st.write(num)
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
# <hr>
#
# #### `Exercise-6`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
# # st.write(num)
#
# col1.button("Add", type="primary",
#             on_click=add_to_celsius,
#             args=(num,))
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)
#
# ![image-16.png](attachment:image-16.png)
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-18.png](attachment:image-18.png)
#
# <hr>
#
# #### `Exercise-6`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
# # st.write(num)
#
# col1.button("Add", type="primary",
#             on_click=add_to_celsius,
#             args=(num,))
#
# col1.button('🧊 Freezing point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=0.00, farenheit=32.00, kelvin=273.15))
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-19.png](attachment:image-19.png)
#
# ![image-20.png](attachment:image-20.png)
#
# ![image-21.png](attachment:image-21.png)
#
# ![image-22.png](attachment:image-22.png)
#
# <hr>
#
# #### `Exercise-7`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
# col2.number_input("Farenheit", step=0.01, key="farenheit", on_change=farenheit_conversion)
# col3.number_input("Kelvin", step=0.01, key="kelvin", on_change=kelvin_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
# # st.write(num)
#
# col1.button("Add", type="primary",
#             on_click=add_to_celsius,
#             args=(num,))
#
# col1.button('🧊 Freezing point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=0.00, farenheit=32.00, kelvin=273.15))
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-23.png](attachment:image-23.png)
#
# ![image-24.png](attachment:image-24.png)
#
# ![image-25.png](attachment:image-25.png)
#
# ![image-26.png](attachment:image-26.png)
#
# <hr>
#
# #### `Exercise-8`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
# col2.number_input("Farenheit", step=0.01, key="farenheit", on_change=farenheit_conversion)
# col3.number_input("Kelvin", step=0.01, key="kelvin", on_change=kelvin_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
# # st.write(num)
#
# col1.button("Add", type="primary",
#             on_click=add_to_celsius,
#             args=(num,))
#
# col1.button('🧊 Freezing point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=0.00, farenheit=32.00, kelvin=273.15))
#
# col2.button('🔥 Boiling point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=100.00, farenheit=212.00, kelvin=373.15))
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-27.png](attachment:image-27.png)
#
# ![image-28.png](attachment:image-28.png)
#
# ![image-29.png](attachment:image-29.png)
#
# `Click on 🧊 Freezing point of water`
#
# ![image-30.png](attachment:image-30.png)
#
# `click on "+" on Farenheit`
#
# ![image-31.png](attachment:image-31.png)
#
# `Click on 🔥 Boiling point of water`
#
# ![image-32.png](attachment:image-32.png)
#
# <hr>
#
# #### `Exercise-8`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#     # st.write("Celsius = ", st.session_state['celsius'])
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#     # st.write("Farenheit = ", st.session_state['farenheit'])
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#     # st.write("Kelvin = ", st.session_state['kelvin'])
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
# col2.number_input("Farenheit", step=0.01, key="farenheit", on_change=farenheit_conversion)
# col3.number_input("Kelvin", step=0.01, key="kelvin", on_change=kelvin_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
# # st.write(num)
#
# col1.button("Add", type="primary",
#             on_click=add_to_celsius,
#             args=(num,))
#
# col1.button('🧊 Freezing point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=0.00, farenheit=32.00, kelvin=273.15))
#
# col2.button('🔥 Boiling point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=100.00, farenheit=212.00, kelvin=373.15))
#
# col3.button('🥶 Absolute zero',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=-273.15, farenheit=-459.67, kelvin=0.00))
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image-33.png](attachment:image-33.png) <br>
#
# `click on "+" on Farenheit`
# ![image-34.png](attachment:image-34.png) <br>
#
# `🥶 Absolute zero`
# ![image-35.png](attachment:image-35.png) <br>
#
# `Added to Celsius -> 5`
# ![image-36.png](attachment:image-36.png) <br>
#
# ![image-37.png](attachment:image-37.png) <br>
#
# `🔥 Boiling point of water`
#
# ![image-38.png](attachment:image-38.png) <br>
#
# `🧊 Freezing point of water`
#
# ![image-39.png](attachment:image-39.png)
# <hr>

# %% [markdown]
# #### `Exercise: State Management`
# ```Python
# import streamlit as st
#
# st.title("Exercise: State Management")
# st.subheader("Temperature conversion")
#
# if "celsius" not in st.session_state:
#     st.session_state['celsius'] = 0.00
#
# if "farenheit" not in st.session_state:
#     st.session_state['farenheit'] = 32.00
#
# if "kelvin" not in st.session_state:
#     st.session_state['kelvin'] = 273.15
#
# def celsius_conversion():
#     celsius = st.session_state['celsius']
#
#     st.session_state['farenheit'] = (celsius * 9 / 5) + 32
#     st.session_state['kelvin'] = celsius + 273.15
#
# def farenheit_conversion():
#     farenheit = st.session_state['farenheit']
#
#     st.session_state['celsius'] = (farenheit - 32) * 5 / 9
#     st.session_state['kelvin'] = (farenheit - 32) * 5 / 9 + 273.15
#
# def kelvin_conversion():
#     kelvin = st.session_state['kelvin']
#
#     st.session_state['celsius'] = kelvin - 273.15
#     st.session_state['farenheit'] = (kelvin - 273.15) * 9 / 5 + 32
#
# def add_to_celsius(num):
#     st.session_state['celsius'] += num
#     celsius_conversion()
#
# def set_temperatures(celsius, farenheit, kelvin):
#     st.session_state['celsius'] = celsius
#     st.session_state['farenheit'] = farenheit
#     st.session_state['kelvin'] = kelvin
#
# col1, col2, col3 = st.columns(3)
#
# col1.number_input("Celsius", step=0.01, key="celsius", on_change=celsius_conversion)
# col2.number_input("Farenheit", step=0.01, key="farenheit", on_change=farenheit_conversion)
# col3.number_input("Kelvin", step=0.01, key="kelvin", on_change=kelvin_conversion)
#
# col1, _, _ = st.columns(3)
# num = col1.number_input("Add to Celsius", step=1)
#
# col1.button("Add", type="primary",
#             on_click=add_to_celsius,
#             args=(num,))
#
# col1, col2, col3 = st.columns(3)
#
# col1.button('🧊 Freezing point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=0.00, farenheit=32.00, kelvin=273.15))
#
# col2.button('🔥 Boiling point of water',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=100.00, farenheit=212.00, kelvin=373.15))
#
# col3.button('🥶 Absolute zero',
#             on_click=set_temperatures,
#             kwargs=dict(celsius=-273.15, farenheit=-459.67, kelvin=0.00))
#
# st.write(st.session_state)
# ```
# <hr>
#
# #### `Streamlit Output`
# ![image.png](attachment:image.png) <br>
#
# `Add to Celsius -> 5`
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png) <br>
#
# `🧊 Freezing point of water`
# ![image-4.png](attachment:image-4.png) <br>
#
# `🔥 Boiling point of water`
# ![image-5.png](attachment:image-5.png) <br>
#
# `🥶 Absolute zero`
# ![image-6.png](attachment:image-6.png) <br>
#
# <hr>
